# %%
import matplotlib.pyplot as plt
import pandas as pd

# Read data
file_path = 'cscpopendata.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#    CDPHId                                       ProductName  CSFId  CSF  \
# 0       2  ULTRA COLOR RICH EXTRA PLUMP LIPSTICK-ALL SHADES    NaN  NaN
# 1       3                        Glover's Medicated Shampoo    NaN  NaN
# 2       3                        Glover's Medicated Shampoo    NaN  NaN
# 3       4          PRECISION GLIMMER EYE LINER-ALL SHADES �    NaN  NaN
# 4       5       AVON BRILLIANT SHINE LIP GLOSS-ALL SHADES �    NaN  NaN
#
#    CompanyId          CompanyName BrandName  PrimaryCategoryId  \
# 0          4         New Avon LLC      AVON                 44
# 1        338  J. Strickland & Co.  Glover's                 18
# 2        338  J. Strickland & Co.  Glover's                 18
# 3          4         New Avon LLC      AVON                 44
# 4          4         New Avon LLC      AVON                 44
#
#                      PrimaryCategory  SubCategoryId  ...   CasNumber  \
# 0    Makeup Products (non-permanent)             53  ...  13463-67-7
# ...

# %%
# Extract chemical data and remove duplicates
chemical_data = data[['ChemicalName', 'CasNumber']]
# Out:
#                ChemicalName   CasNumber
# 0          Titanium dioxide  13463-67-7
# 1    Distillates (coal tar)  65996-92-1
# 2                 Estragole    140-67-0
# 31  Cocamide diethanolamine  68603-42-9
# 45                  Toluene    108-88-3

# %%
# Count occurrences and get the top 10 chemicals
chemical_counts = unique_chemical_counts['ChemicalName'].value_counts()
top_10_chemicals = chemical_counts.head(10)
top_10_chemicals
# Out:
# ChemicalName
# Titanium dioxide                                                                                       11
# Retinyl palmitate                                                                                       9
# Retinol/retinyl esters, when in daily dosages in excess of 10,000 IU, or 3,000 retinol equivalents.     7
# Cocamide diethanolamine                                                                                 6
# Carbon black (airborne, unbound particles of respirable size)                                           3
# Vitamin A                                                                                               3
# Methyleugenol                                                                                           3
# Talc                                                                                                    3
# Coal Tar                                                                                                2
# ...

# %%
# Defining a function for shortening the names on the chart
def shorten_name(name):
    return name if len(name) <= 30 else name[:30] + '...'
shortened_labels = [shorten_name(name) for name in top_10_chemicals.index]

# %%
# Create pie chart
plt.figure(figsize=(10, 10))
plt.pie(top_10_chemicals.values, labels=shortened_labels, autopct='%1.1f%%',
        startangle=140, textprops={'fontsize': 12}, wedgeprops={'edgecolor': 'black'})

# Set title and layout
plt.title('Top 10 Toxic Chemicals Found', fontsize=14)
plt.tight_layout()

# Show chart
plt.show()

# %%
# Print shortened chemical names and their counts
print(top_10_chemicals)
# Out:
# ChemicalName
# Titanium dioxide                                                                                       11
# Retinyl palmitate                                                                                       9
# Retinol/retinyl esters, when in daily dosages in excess of 10,000 IU, or 3,000 retinol equivalents.     7
# Cocamide diethanolamine                                                                                 6
# Carbon black (airborne, unbound particles of respirable size)                                           3
# Vitamin A                                                                                               3
# Methyleugenol                                                                                           3
# Talc                                                                                                    3
# Coal Tar                                                                                                2
# ...
